# %%
import pandas as pd
import numpy as np
import streamlit as st
import joblib
import shap
import matplotlib.pyplot as plt
import warnings
from pathlib import Path
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.inspection import permutation_importance

warnings.filterwarnings("ignore")

# ============================================================
# 📁 PATH CONFIG
# ============================================================
BASE_DIR = Path.cwd()
DATA_DIR = BASE_DIR / "processed_data"
MODELS_DIR = BASE_DIR / "models"
DATA_DIR.mkdir(exist_ok=True)
MODELS_DIR.mkdir(exist_ok=True)

DATA_FILE = DATA_DIR / "personalized_nsga2_results.csv"
MODEL_FILE = MODELS_DIR / "personalized_rf_model.joblib"
SCALER_FILE = MODELS_DIR / "personalized_scaler.joblib"

# ============================================================
# 🧩 Streamlit Setup
# ============================================================
st.set_page_config(page_title="🥗 Personalized NSGA-II Optimizer + XAI", layout="wide")
st.title("🥗 Personalized Recipe Optimization Dashboard")
st.markdown("Uses **NSGA-II** + **Explainable AI (XAI)** to generate personalized, sustainable meal recommendations.")

# ============================================================
# 📥 Load Dataset (with fallback)
# ============================================================
@st.cache_data
def load_data():
    if not DATA_FILE.exists():
        st.error(f"❌ File not found: {DATA_FILE}")
        return pd.DataFrame()

    df = pd.read_csv(DATA_FILE)
    df = df.loc[:, ~df.columns.duplicated()].copy()

    # Ensure numeric columns exist
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    if len(num_cols) == 0:
        st.error("❌ No numeric features found in dataset!")
        return pd.DataFrame()

    # Create preference score if missing
    if "_preference_score" not in df.columns:
        df["_preference_score"] = df[num_cols].mean(axis=1).rank(pct=True)
        st.warning("⚠️ '_preference_score' not found. Created placeholder values.")

    return df

df = load_data()
if df.empty:
    st.stop()

st.success(f"✅ Loaded {df.shape[0]} optimized recipes")

# ============================================================
# ⚙️ Load / Train Model and Scaler
# ============================================================
@st.cache_resource
def get_model_and_scaler(df):
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

    if MODEL_FILE.exists() and SCALER_FILE.exists():
        model = joblib.load(MODEL_FILE)
        scaler = joblib.load(SCALER_FILE)
        return model, scaler

    st.warning("⚠️ No saved model found — training new Random Forest model...")

    X = df[numeric_cols].fillna(df[numeric_cols].mean())
    y = df["_preference_score"]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    model = RandomForestRegressor(n_estimators=200, random_state=42)
    model.fit(X_scaled, y)

    joblib.dump(model, MODEL_FILE)
    joblib.dump(scaler, SCALER_FILE)
    st.success("✅ Model trained and saved successfully.")

    return model, scaler

model, scaler = get_model_and_scaler(df)

# ============================================================
# 🧠 Feature Importance (XAI)
# ============================================================
@st.cache_data
def compute_feature_importance(model, df):
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    X_scaled = MinMaxScaler().fit_transform(df[numeric_cols])
    result = permutation_importance(model, X_scaled, df["_preference_score"], n_repeats=10, random_state=42)
    importance_df = pd.DataFrame({
        "Feature": numeric_cols,
        "Importance": result.importances_mean
    }).sort_values("Importance", ascending=False)
    return importance_df

importance_df = compute_feature_importance(model, df)
st.markdown("### 🔍 Model Feature Importance")
st.bar_chart(importance_df.set_index("Feature")["Importance"])

# ============================================================
# 🎯 User Preferences
# ============================================================
st.sidebar.header("🧍 Personalized Preferences")
energy_pref = st.sidebar.slider("Energy (kcal)", 1200, 3000, 1800)
protein_pref = st.sidebar.slider("Protein (g)", 10, 200, 60)
carbs_pref = st.sidebar.slider("Carbs (g)", 20, 300, 150)
fat_pref = st.sidebar.slider("Fat (g)", 10, 150, 50)
price_pref = st.sidebar.slider("Price ($)", 1.0, 20.0, 8.0)
emission_pref = st.sidebar.slider("Emission (kgCO₂e)", 0.1, 10.0, 3.0)

# ============================================================
# 🎯 Personalized Scoring
# ============================================================
def personalized_score(row):
    score = (
        0.25 * (1 - abs(row.get("energy_kcal_mean", 0) - energy_pref) / max(energy_pref, 1))
        + 0.25 * (1 - abs(row.get("protein_g_mean", 0) - protein_pref) / max(protein_pref, 1))
        + 0.15 * (1 - abs(row.get("fat_g_mean", 0) - fat_pref) / max(fat_pref, 1))
        + 0.15 * (1 - abs(row.get("carbs_g_mean", 0) - carbs_pref) / max(carbs_pref, 1))
        + 0.1  * (1 - abs(row.get("price_mean", 0) - price_pref) / max(price_pref, 1))
        + 0.1  * (1 - abs(row.get("Total_emissions_mean", 0) - emission_pref) / max(emission_pref, 1))
    )
    return score

df["_personalized_score"] = df.apply(personalized_score, axis=1)
filtered = df.sort_values("_personalized_score", ascending=False).head(10)

# ============================================================
# 🧩 Display Top Recipe & SHAP Explanation
# ============================================================
if not filtered.empty:
    st.subheader("🍽️ Top Personalized Recipe")

    sel_row = filtered.iloc[[0]]
    features = [c for c in df.select_dtypes(include=[np.number]).columns if "mean" in c]
    sel_row = sel_row.loc[:, ~sel_row.columns.duplicated()].copy()

    cols_to_show = [c for c in ["price_mean", "Total_emissions_mean", "_preference_score", "_personalized_score"] if c in sel_row.columns]
    final_cols = features + cols_to_show

    try:
        st.table(pd.DataFrame(sel_row[final_cols]).T)
    except Exception as e:
        st.warning(f"⚠️ Could not render table properly: {e}")
        st.dataframe(sel_row.T)

    # Natural explanation
    st.markdown("**🧠 Natural Language Explanation:**")
    st.markdown(
        f"This recipe offers {sel_row['protein_g_mean'].values[0]:.1f}g protein, "
        f"{sel_row['carbs_g_mean'].values[0]:.1f}g carbs, and a satisfaction score of "
        f"{sel_row['_personalized_score'].values[0]:.2f}. "
        "It fits well with your current dietary preferences."
    )

    # ============================================================
    # 💬 SHAP Explanation
    # ============================================================
    st.markdown("### 🩻 SHAP Explainability (Feature Impact)")
    try:
        X = df[features].fillna(df[features].mean())
        X_scaled = scaler.transform(X)
        explainer = shap.TreeExplainer(model)
        shap_values = explainer.shap_values(X_scaled)
        fig, ax = plt.subplots(figsize=(10, 4))
        shap.summary_plot(shap_values, X, plot_type="bar", show=False)
        st.pyplot(fig)
    except Exception as e:
        st.warning(f"⚠️ SHAP visualization failed: {e}")

else:
    st.warning("⚠️ No recipes matched your preferences. Adjust the sliders and retry.")
# Out:
# 2025-11-07 19:21:15.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.903 No runtime found, using MemoryCacheStorageManager
# 2025-11-07 19:21:15.905 No runtime found, using MemoryCacheStorageManager
# 2025-11-07 19:21:15.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 19:21:15.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 95
#      91     st.success("✅ Model trained and saved successfully.")
#      93     return model, scaler
# ---> 95 model, scaler = get_model_and_scaler(df)
#      97 # ============================================================
#      98 # 🧠 Feature Importance (XAI)
#      99 # ============================================================
#     100 @st.cache_data
#     101 def compute_feature_importance(model, df):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\streamlit\runtime\caching\cache_utils.py:227, in CachedFunc.__call__(self, *args, **kwargs)
#     224     else:
#     225         spinner_message = f"Running `{name}(...)`."
# --> 227 return self._get_or_create_cached_value(args, kwargs, spinner_message)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\streamlit\runtime\caching\cache_utils.py:269, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs, spinner_message)
#     263 spinner_or_no_context = (
#     264     spinner(spinner_message, _cache=True, show_time=self._info.show_time)
#     265     if spinner_message is not None and not is_nested_cache_function
#     266     else contextlib.nullcontext()
#     267 )
#     268 with spinner_or_no_context:
# --> 269     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\streamlit\runtime\caching\cache_utils.py:328, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     324 # We acquired the lock before any other thread. Compute the value!
#     325 with self._info.cached_message_replay_ctx.calling_cached_function(
#     326     self._info.func
#     327 ):
# --> 328     computed_value = self._info.func(*func_args, **func_kwargs)
#     330 # We've computed our value, and now we need to write it back to the cache
#     331 # along with any "replay messages" that were generated during value computation.
#     332 messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# Cell In[9], line 81, in get_model_and_scaler(df)
#      78 st.warning("⚠️ No saved model found — training new Random Forest model...")
#      80 X = df[numeric_cols].fillna(df[numeric_cols].mean())
# ---> 81 y = df["_preference_score"]
#      83 scaler = MinMaxScaler()
#      84 X_scaled = scaler.fit_transform(X)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: '_preference_score'
